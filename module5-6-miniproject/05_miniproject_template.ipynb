# %% [markdown]
# # Mini-Project: [Your Title Here]
# **Intern:** [Your name]
# **Date:** [Start date]
# **Dataset:** [Describe the dataset you're working with]

# %% [markdown]
# ---
# ## Part 1 — Dataset Exploration
# *(Week 5, Days 1–2)*

# %% [markdown]
# Use Claude Code to explore the dataset. Run file listing, check formats, understand what organism and experiment this represents.

# %%
# %%bash
# # Explore the data/ directory
# # What files exist? What formats? What size?

# %% [markdown]
# **Dataset summary:** (describe what files you found, what format, what organism, what experiment type)

# %% [markdown]
# [Your summary here]

# %% [markdown]
# ---
# ## Part 2 — Literature Context
# *(Week 5, Day 2)*

# %% [markdown]
# Use Claude to find what is already known about the gene, regulator, or condition in this dataset. Extract any reference gene lists or coordinates from relevant papers.

# %% [markdown]
# **What is known:** (3–5 sentences summarizing the literature context — cite papers if possible)

# %% [markdown]
# [Your literature summary here]

# %% [markdown]
# **Reference data extracted from literature:** (if you extracted gene lists or coordinates using Claude, describe what you got and how you validated it)

# %%
# Paste extracted reference data here
# e.g., gene lists, genomic coordinates, known targets

# %% [markdown]
# ---
# ## Part 3 — Biological Question
# *(Week 5, Days 2–3)*

# %% [markdown]
# Propose one specific, answerable biological question based on your dataset and literature context. Be specific — include the condition, organism, threshold, or comparison where relevant.

# %% [markdown]
# **Instructor check-in required before proceeding to Part 4.**

# %% [markdown]
# [Your biological question here]

# %% [markdown]
# ---
# ## Part 4 — Analysis Plan
# *(Week 5, Day 3)*

# %% [markdown]
# Write your analysis plan in plain English. This is your own thinking — Claude Code may be consulted, but the plan must be yours.

# %% [markdown]
# Your plan should answer: (1) What input data will you use? (2) What steps will you run? (3) What output do you expect? (4) How will you know if the result is meaningful?

# %% [markdown]
# [Your analysis plan here]

# %% [markdown]
# **Pipeline scaffold** — Use plan mode (Shift+Tab) to generate the pipeline. Review every step. Annotate each command with your own understanding of what it does.

# %%
# Pipeline scaffold — generated with plan mode, annotated by you

# %% [markdown]
# ---
# ## Part 5 — Analysis Execution
# *(Week 5 Days 4–5 + Week 6 Days 1–3)*

# %% [markdown]
# Run your pipeline here. Add code cells as needed. When blocked, use `/debug` before asking for help.

# %%
# First pipeline step

# %% [markdown]
# Add more cells below as you work.

# %% [markdown]
# ---
# ## Part 6 — Results
# *(Week 6, Days 1–3)*

# %% [markdown]
# Document your results. Include figures. Each figure should have a 1–2 sentence caption describing what it shows.

# %%
# Figure generation

# %% [markdown]
# [Figure caption: describe what this figure shows in 1–2 sentences]

# %% [markdown]
# Add more result cells as needed.

# %% [markdown]
# ---
# ## Part 7 — Report
# *(Week 6, Days 4–5)*

# %% [markdown]
# Write your analysis report. This is your own writing.

# %% [markdown]
# ### Question
# (one sentence)

# %% [markdown]
# [Your question here]

# %% [markdown]
# ### Methods
# (describe what you did — tools, parameters, datasets)

# %% [markdown]
# [Your methods here]

# %% [markdown]
# ### Results
# (what did you find?)

# %% [markdown]
# [Your results here]

# %% [markdown]
# ### Interpretation
# (what does this mean biologically? How does it compare to what was known?)

# %% [markdown]
# [Your interpretation here]

# %% [markdown]
# ### Limitations
# (what would you do differently with more time?)

# %% [markdown]
# [Your limitations here]

# %% [markdown]
# ---
#
# Run `/log` for a final session entry. Submit this notebook as your deliverable.
